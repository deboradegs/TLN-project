# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
from collections import Counter
from tabulate import tabulate

# %%
lemmatizer = WordNetLemmatizer()
vector_dimension = 3
stop_words = stopwords.words('english')
stop_words.extend(['someone', 'something', 'e', 'e.g', 'u', 'ha', 'e.i', 'others', "'s"])
string_punctuation = string.punctuation + '’'

# %%
concept_definitions = pd.read_excel('../resources/definizioni.xlsx', index_col=0).T.to_dict('list')

# %%
def text_preprocessing(text):
    words = list()
    for word in word_tokenize(text.lower()):
        lemma = lemmatizer.lemmatize(word)
        if lemma not in stop_words and lemma not in string_punctuation:
            words.append(lemma)
    return words

# %%
def get_common_words():
    concept_common_words = dict()
    for key, value in concept_definitions.items():
        common_words = list()
        for definition in value:
            if definition == definition:
                common_words.extend(text_preprocessing(definition))
        concept_common_words[key] = [lemma for lemma, count in Counter(common_words).most_common(vector_dimension)]
    return concept_common_words


concept_common_words = get_common_words()
print(concept_common_words)
# Out:
# {'Emotion': ['feeling', 'human', 'feel'], 'Person': ['human', 'person', 'living'], 'Revenge': ['anger', 'feeling', 'action'], 'Brick': ['used', 'object', 'material']}

# %%
def get_synsets_from_genus():
    concept_genus_synsets = dict()
    for key, value in concept_common_words.items():
        genus_synstes = list()
        for word in value:
            genus_synstes.extend(wn.synsets(word))
        genus_synstes = list(dict.fromkeys(genus_synstes))
        concept_genus_synsets[key] = genus_synstes
    return concept_genus_synsets


concept_genus_synsets = get_synsets_from_genus()

# %%
def get_hyponyms_from_genus():
    for key, value in concept_genus_synsets.items():
        for synset in value:
            concept_genus_synsets[key].extend(synset.hyponyms())
            concept_genus_synsets[key] = list(dict.fromkeys(concept_genus_synsets[key]))

get_hyponyms_from_genus()

# %%
def get_context(synset):
    context = list()
    context.extend(text_preprocessing(synset.definition()))
    for example in synset.examples():
        context.extend(text_preprocessing(example))
    context = list(dict.fromkeys(context))
    print(context)
    return context


def weighted_overlap_score(v1, v2, key):
    weight = 1
    overlap = set(v1) & set(v2)
    #for word in overlap:
        #weight += concept_common_words[key].index(word)
    score = float(len(overlap)) / (len(set(v1) | set(v2)))
    return score


def rank_synsets(synsets, key):
    synsets_ranked = list()
    common_words = concept_common_words[key]
    for synset in synsets:
        synsets_ranked.append((synset, weighted_overlap_score(common_words, get_context(synset), key)))
    return sorted([item for item in synsets_ranked if item[1] > 0], key=lambda item: item[1], reverse=True)

# %%
def get_genus_synsets_ranked():
    concept_genus_synsets_ranked = dict()
    for key, value in concept_genus_synsets.items():
        concept_genus_synsets_ranked[key] = rank_synsets(value, key)[:5]
    return concept_genus_synsets_ranked


concept_genus_synsets_ranked = get_genus_synsets_ranked()
# Out:
# ['experiencing', 'affective', 'emotional', 'state', 'feeling', 'euphoria', 'terrible', 'guilt', 'disliked', 'wa', 'mutual']
# ['vague', 'idea', 'confidence', 'placed', 'impression', 'wa', 'favorable', 'feeling', 'crisis', 'strengthened', 'belief', 'sincerity', 'lying']
# ['general', 'atmosphere', 'place', 'situation', 'effect', 'people', 'feel', 'city', 'excited', 'clergyman', 'improved', 'tone', 'meeting', 'smell', 'treason']
# ['physical', 'sensation', 'experience', 'queasy', 'feeling', 'strange', 'leg', 'lost', 'arm']
# ['sensation', 'produced', 'pressure', 'receptor', 'skin', 'like', 'touch', 'silk', 'surface', 'greasy', 'feeling']
# ['intuitive', 'understanding', 'great', 'feeling', 'music']
# ['undergo', 'emotional', 'sensation', 'particular', 'state', 'mind', 'felt', 'resentful', 'regret']
# ['come', 'believe', 'basis', 'emotion', 'intuition', 'indefinite', 'ground', 'feel', 'doe', "n't", 'like', 'find', 'obnoxious', 'found', 'movie', 'rather', 'entertaining']
# ['perceive', 'physical', 'sensation', 'e.g.', 'coming', 'skin', 'muscle', 'felt', 'wind', 'object', 'brushing', 'arm', 'flesh', 'crawl', 'heat', 'got', 'car']
# ['conscious', 'physical', 'mental', 'emotional', 'state', 'cold', 'gone', '--', 'feel', 'fine', 'today', 'felt', 'tired', 'long', 'hike', 'sad', 'loss']
# ['feeling', 'perception', 'oneself', 'reaction', 'behavior', 'attitude', 'felt', 'small', 'insignificant', 'make', 'feel', 'naked', 'made', 'student', 'different']
# ['undergo', 'passive', 'experience', 'felt', 'effect', 'inflation', 'finger', 'way', 'string', 'quartet', 'contempt']
# ['felt', 'perceived', 'certain', 'way', 'ground', 'feel', 'shaky', 'sheet', 'soft']
# ['grope', 'feel', 'search', 'felt', 'wallet']
# ['examine', 'touch', 'feel', 'soft', 'cloth', 'customer', 'fingered', 'sweater']
# ['examine', 'body', 'part', 'palpation', 'nurse', 'palpated', 'patient', 'stomach', 'runner', 'felt', 'pulse']
# ['find', 'testing', 'cautious', 'exploration', 'felt', 'way', 'around', 'dark', 'room']
# ['produce', 'certain', 'impression', 'feel', 'nice', 'home']
# ['pas', 'one', 'hand', 'sexual', 'organ', 'felt', 'girl', 'movie', 'theater']
# ['living', 'extinct', 'member', 'family', 'hominidae', 'characterized', 'superior', 'intelligence', 'articulate', 'speech', 'erect', 'carriage']
# ['characteristic', 'humanity', 'human', 'nature']
# ['relating', 'person', 'experiment', 'wa', 'conducted', '6', 'monkey', '2', 'human', 'subject']
# ['human', 'form', 'attribute', 'opposed', 'animal', 'divine', 'body', 'kindness', 'frailty']
# ['intuitive', 'awareness', 'feel', 'animal', 'easy', 'get']
# ['property', 'perceived', 'touch']
# ['manual', 'stimulation', 'genital', 'area', 'sexual', 'pleasure', 'girl', 'hated', 'tried', 'sneak', 'feel']
# ['conscious', 'subjective', 'aspect', 'feeling', 'emotion']
# ['positive', 'feeling', 'liking', 'trouble', 'expressing', 'affection', 'felt', 'child', 'everyone', 'heart', 'warmness', 'welcome', 'made', 'feel', 'right', 'home']
# ['feeling', 'agitated', 'calm']
# ['mixed', 'feeling', 'emotion']
# ['absence', 'emotion', 'enthusiasm']
# ['feeling', 'accompanies', 'extremely', 'surprising', 'looked', 'astonishment']
# ['feeling', 'calm', 'absence', 'agitation', 'excitement']
# ['psychoanalysis', 'combination', 'emotion', 'impulse', 'rejected', 'awareness', 'still', 'influence', 'person', 'behavior']
# ['feeling', 'accompanies', 'unsatisfied', 'state']
# ['feeling', 'everything', 'wrong', 'nothing', 'turn', 'well', 'moaned', 'despair', 'dismay', 'one', 'harsh', 'word', 'would', 'send', 'depth']
# ['feeling', 'confounded', 'overwhelmed', 'departure', 'left', 'utter', 'devastation']
# ['feeling', 'aversion', 'antipathy', 'dislike', 'wa', 'instinctive']
# ['strong', 'feeling']
# ['feeling', 'excitement']
# ['feeling', 'happen']
# ['feeling', 'faintness', 'ready', 'swoon']
# ['feeling', 'fear']
# ['feeling', 'considerable', 'warmth', 'glow', 'new', 'love', 'regret']
# ['feeling', 'thankfulness', 'appreciation', 'wa', 'overwhelmed', 'gratitude', 'help']
# ['solemn', 'dignified', 'feeling']
# ['emotion', 'experienced', 'state', 'well-being']
# ['general', 'feeling', 'desire', 'fulfilled', 'spite', 'trouble', 'never', 'gave', 'hope']
# ['humble', 'feeling', 'wa', 'filled', 'humility', 'sight', 'pope']
# ['lack', 'gratitude']
# ['feeling', 'inappropriate', 'lack', 'seriousness']
# ['feeling', 'pleasure', 'enjoyment', "'ve", 'always', 'liking', 'reading', 'developed', 'gin']
# ['emotional', 'distress', 'fundamental', 'feeling', 'people', 'try', 'avoid', 'pain', 'loneliness']
# ['sudden', 'sharp', 'feeling', 'pang', 'regret', 'felt', 'stab', 'excitement', 'twinge', 'conscience']
# ['strong', 'feeling', 'emotion']
# ['fundamental', 'feeling', 'hard', 'define', 'people', 'desire', 'experience', 'wa', 'tingling', 'pleasure']
# ['feeling', 'self-respect', 'personal', 'worth']
# ['emotion', 'experienced', 'state', 'well-being']
# ['sensitivity', 'emotional', 'feeling', 'self']
# ['tender', 'romantic', 'nostalgic', 'feeling', 'emotion']
# ['feeling', 'resulting', 'urge', 'gratify', 'sexual', 'impulse', 'wanted', 'better', 'sex', 'life', 'film', 'contained', 'violence']
# ['painful', 'emotion', 'resulting', 'awareness', 'inadequacy', 'guilt']
# ['deep', 'feeling', 'emotion']
# ['sharing', 'feeling', 'especially', 'sorrow', 'anguish']
# ['characteristic', 'habitual', 'relatively', 'temporary', 'state', 'feeling', 'whether', 'praised', 'cursed', 'depended', 'temper', 'time', 'wa', 'bad', 'humor']
# ['persistent', 'illogical', 'feeling', 'desire', 'aversion', 'thing', 'seafood']
# ['feeling', 'lack', 'concern']
# ['impression', 'especially', 'one', 'artificial', 'contrived', 'effect']
# ['first', 'glimpse', 'impression', 'blush', 'idea', 'posse', 'considerable', 'intuitive', 'appeal', 'closer', 'examination', 'fails']
# ['impression', 'might', 'case', 'intuition', 'gone', 'wrong']
# ['impression', 'present', 'felt', 'presence', 'evil', 'force']
# ['flashy', 'vulgar', 'tone', 'atmosphere', 'believed', 'characteristic', 'american', 'film', 'industry', 'people', 'publishing', 'think', 'glamorous', 'medium', 'copy', 'glitter', 'hollywood']
# ['spirit', 'time', 'characteristic', 'age', 'generation']
# ['tight', 'feeling', 'part', 'body', 'felt', 'constriction', 'chest', 'alarming', 'tightness', 'emotion', 'caused', 'throat']
# ['uneasy', 'sensation', 'insect', 'creeping', 'skin']
# ['sensation', 'localized', 'skin']
# ['intuitive', 'feeling', 'natural', 'idiom', 'language', 'dubyuh', 'sprachgefuhl']
# ['become', 'angry', 'anger', 'easily']
# ['feel', 'strong', 'emotion', 'especially', 'anger', 'passion', 'wa', 'burning', 'try', 'new', 'sky']
# ['feel', 'extreme', 'irritation', 'anger', 'wa', 'chafing', 'suggestion', 'stay', 'home', 'went', 'vacation']
# ['feel', 'le', 'enamoured', 'somebody']
# ['feel', 'indifferent', 'towards', 'died', 'worldly', 'thing', 'eventually', 'entered', 'monastery']
# ['elated', 'wa', 'flying', 'high', 'summer', 'month']
# ['mad', 'angry', 'furious']
# ['exuberant', 'high-spirited', 'make', 'people', 'heart', 'glow']
# ['experience', 'feeling', 'well-being', 'happiness', 'good', 'health', 'intense', 'emotion', 'wa', 'beaming', 'joy', 'face', 'radiated']
# ['maintain', 'theory', 'thought', 'feeling', 'bear', 'grudge', 'entertain', 'interesting', 'notion', 'harbor', 'resentment']
# ['feel', 'favorably', 'disposed', 'willing', 'incline', 'view', 'people', 'allowed', 'expres', 'religious', 'belief']
# ['proud', 'pride', 'making', 'law', 'school']
# ['experience', 'anew', 'could', 'recapture', 'feeling', 'happiness']
# ['feel', 'happiness', 'joy']
# ['feel', 'remorse', 'sorry', 'contrite']
# ['come', 'feel', 'sad']
# ['strong', 'suppressed', 'feeling']
# ['experience', 'emotional', 'pain', 'every', 'time', 'husband', 'get', 'drunk', 'suffers']
# ['share', 'feeling', 'understand', 'sentiment']
# ['feel', 'proud', 'took', 'great', 'pride', 'son']
# ['excellent', 'health', 'spirit', 'feel', 'like', 'million', 'got', 'promotion']
# ['feel', 'uncomfortable', 'lack', 'fresh', 'air', 'room', 'wa', 'hot', 'stuffy', 'suffocating']
# ['feel', 'crawling', 'insect', 'skin', 'crawled', '--', 'wa', 'terrified']
# ['feel', 'searchingly', 'groped', 'key', 'dark']
# ['extinct', 'specie', 'primitive', 'hominid', 'upright', 'stature', 'small', 'brain', 'homo', 'erectus', 'wa', 'formerly', 'called', 'pithecanthropus']
# ['extinct', 'specie', 'upright', 'east', 'african', 'hominid', 'advanced', 'humanlike', 'characteristic']
# ['surviving', 'hominid', 'specie', 'modern', 'man', 'belongs', 'bipedal', 'primate', 'language', 'ability', 'make', 'use', 'complex', 'tool', 'brain', 'volume', 'least', '1400', 'cc']
# ['extinct', 'primitive', 'hominid', 'late', 'pleistocene', 'java', 'formerly', 'javanthropus']
# ['extinct', 'robust', 'human', 'middle', 'paleolithic', 'europe', 'western', 'asia']
# ['primitive', 'hominid', 'resembling', 'neanderthal', 'man', 'living', 'africa']
# ['living', 'human', 'inhabitant', 'earth', 'world', 'love', 'lover', 'always', 'used', 'humankind', 'mankind', 'seemed', 'slight', 'woman']
# ['feel', 'surface', 'fabric', 'wall', 'smooth', 'texture']
# ['feel', 'mechanical', 'action', 'piano', 'wonderful', 'touch']
# ['feeling', 'affection', 'person', 'institution']
# ['feeling', 'protective', 'affection']
# ['feeling', 'friendship', 'esteem', 'mistook', 'manly', 'regard', 'love', 'inspires', 'respect']
# ['sentimental', 'affection', 'soft', 'spot', 'youngest', 'son']
# ['feeling', 'agitation', 'expressed', 'continual', 'motion', 'got', 'fidget', 'waiting', 'gave', 'restlessness']
# ['extreme', 'state', 'worry', 'agitation', 'stewing', 'fight', 'kept', 'awake', 'night']
# ['emotional', 'agitation', 'excitement']
# ['violent', 'agitation']
# ['feeling', 'restless', 'agitation']
# ['opposition', 'two', 'simultaneous', 'incompatible', 'feeling', 'wa', 'immobilized', 'conflict', 'indecision']
# ['apathy', 'demonstrated', 'absence', 'emotional', 'reaction']
# ['feeling', 'lack', 'interest', 'energy']
# ['feeling', 'stupefied', 'astonishment']
# ['astonishment', 'feel', 'totally', 'unexpected', 'happens']
# ['feeling', 'aroused', 'strange', 'surprising']
# ['calm', 'unruffled', 'self-assurance', 'performed', 'coolness', 'veteran']
# ['feeling', 'calmness', 'quiet', 'undisturbed']
# ['state', 'peace', 'quiet']
# ['complex', 'female', 'sexual', 'attraction', 'father']
# ['sense', 'personal', 'inferiority', 'arising', 'conflict', 'desire', 'noticed', 'fear', 'humiliated']
# ['complex', 'male', 'desire', 'posse', 'mother', 'sexually', 'exclude', 'father', 'said', 'source', 'personality', 'disorder', 'unresolved']
# ['cherished', 'desire', 'ambition', 'business']
# ['desire', 'bloodshed']
# ['sudden', 'desire', 'bought', 'impulse']
# ['intense', 'desire', 'particular', 'thing']
# ['prolonged', 'unfulfilled', 'desire', 'need']
# ['desire', 'sexual', 'intimacy']
# ['desire', 'know', 'avoid', 'felt', 'temptation', 'power', 'weakened']
# ['strong', 'restless', 'desire', 'urge', 'travel']
# ['specific', 'feeling', 'desire', 'got', 'wish', 'wa', 'wishing']
# ['feeling', 'despair', 'face', 'obstacle']
# ['despair', 'feel', 'abandoned', 'hope', 'comfort', 'success']
# ['feeling', 'thing', 'turn', 'badly']
# ['acceptance', 'despair']
# ['feeling', 'alienated', 'people']
# ['dislike', 'fear', 'britain', 'british', 'custom']
# ['actively', 'expressed', 'feeling', 'dislike', 'hostility']
# ['feeling', 'intense', 'dislike']
# ['lack', 'respect', 'accompanied', 'feeling', 'intense', 'dislike', 'wa', 'held', 'contempt', 'despite', 'outsider', 'legendary']
# ['feeling', 'dislike', 'anxiety', 'cave', 'gave', 'creepy-crawly']
# ['feeling', 'disliking']
# ['strong', 'feeling', 'dislike']
# ['toward', 'inclined', 'feel', 'dislike', 'disinclination', 'modesty', 'well', 'known']
# ['strong', 'dislike', 'took', 'scunner', 'united', 'state']
# ['dislike', 'new', 'technology']
# ['dislike', 'experienced', 'absence', 'friendliness']
# ['strong', 'emotion', 'feeling', 'oriented', 'toward', 'real', 'supposed', 'grievance']
# ['vague', 'unpleasant', 'emotion', 'experienced', 'anticipation', 'usually', 'ill-defined', 'misfortune']
# ['emotional', 'response', 'acquired', 'conditioning']
# ['state', 'person', 'emotion', 'especially', 'regard', 'pleasure', 'dejection', 'emotional', 'depended', 'opinion', 'wa', 'good', 'spirit', 'rose']
# ['emotion', 'experienced', 'anticipation', 'specific', 'pain', 'danger', 'usually', 'accompanied', 'desire', 'flee', 'fight']
# ['feeling', 'profound', 'respect', 'fear', 'god', 'chinese', 'reverence', 'dead', 'french', 'treat', 'food', 'gentle', 'law', 'bordered', 'veneration']
# ['emotion', 'intense', 'dislike', 'feeling', 'strong', 'demand', 'action']
# ['emotion', 'great', 'happiness']
# ['strong', 'positive', 'emotion', 'regard', 'affection', 'love', 'work', 'child', 'need', 'lot']
# ['positive', 'feeling', 'wanting', 'push', 'ahead']
# ['joyful', 'enthusiasm']
# ['vigorous', 'enthusiastic', 'enjoyment']
# ['enthusiasm', 'new', 'technology']
# ['expectation']
# ['freedom', 'anxiety', 'fear', 'watch', 'dog', 'gave', 'feeling', 'security']
# ['warm', 'friendly', 'feeling', 'gratitude']
# ['earnest', 'sincere', 'feeling']
# ['happiness', 'felt', 'secure', 'relationship', 'classmate', 'sense', 'belonging']
# ['french', 'happiness', 'good', 'humor']
# ['feeling', 'spontaneous', 'good', 'spirit', 'cheerfulness', 'made', 'everyone', 'feel', 'better']
# ['happiness', 'one', 'situation', 'life']
# ['gay', 'feeling']
# ['experiencing', 'joy', 'pleasure']
# ['feeling', 'great', 'happiness']
# ['feeling', 'encouraged']
# ['feeling', 'hope']
# ['optimistic', 'feeling', 'going', 'turn', 'well']
# ['feeling', 'patient', 'submissive', 'humbleness']
# ['feeling', 'little', 'worth']
# ['festive', 'merry', 'feeling']
# ['feeling', 'delighted', 'approval', 'liking']
# ['feeling', 'liking', 'good', 'although', 'fussed', 'secretly', 'viewed', 'child', 'approval']
# ['feeling', 'great', 'liking', 'wonderful', 'unusual']
# ['predisposition', 'like', 'fondness', 'whiskey']
# ['feeling', 'liking', 'another', 'person', 'enjoyment', 'company']
# ['toward', 'inclined', 'feel', 'liking', 'inclination', 'classical', 'music']
# ['abnormal', 'attraction', 'filth']
# ['strong', 'liking', 'preference', 'good', 'literature', 'irish', 'penchant', 'blarney']
# ['psychological', 'suffering', 'death', 'wife', 'caused', 'great', 'distress']
# ['emotional', 'distress', 'arising', 'adolescence']
# ['sustained', 'dull', 'painful', 'emotion']
# ['feeling', 'mental', 'physical', 'pain']
# ['feeling', 'caused', 'disagreeable', 'stimulus', 'one', 'pole', 'continuum', 'state']
# ['pang', 'feeling', 'guilty']
# ['feeling', 'great', 'warmth', 'intensity', 'spoke', 'ardor']
# ['foolish', 'usually', 'extravagant', 'passion', 'love', 'admiration']
# ['violent', 'passion', 'speech', 'action', 'frightened', 'storminess', 'argument']
# ['feeling', 'extreme', 'emotional', 'intensity', 'wildness', 'anger']
# ['feeling', 'freedom', 'worry', 'disappointment']
# ['feeling', 'extreme', 'pleasure', 'satisfaction', 'delight', 'see', 'wa', 'obvious']
# ['pleasure', 'felt', 'good', 'time']
# ['feeling', 'caused', 'agreeable', 'stimulus', 'one', 'pole', 'continuum', 'state']
# ['pleasure', 'derived', 'sexual', 'activity']
# ['feeling', 'excessive', 'pride']
# ['quality', 'worthy', 'esteem', 'respect', 'wa', 'beneath', 'dignity', 'cheat', 'showed', 'true', 'pressure']
# ['inflated', 'feeling', 'pride', 'superiority']
# ['feeling', 'pride']
# ['feeling', 'dreary', 'pessimistic', 'sadness']
# ['sad', 'feeling', 'gloom', 'inadequacy']
# ['sadness', 'caused', 'grief', 'affliction']
# ['feeling', 'low', 'spirit', 'felt', 'responsible', 'lowness']
# ['sadness', 'resulting', 'forsaken', 'abandoned']
# ['persisting', 'sadness', 'nothing', 'lifted', 'heaviness', 'heart', 'loss']
# ['feeling', 'thoughtful', 'sadness']
# ['feeling', 'intense', 'unhappiness', 'wa', 'exhausted', 'misery', 'grief']
# ['emotion', 'great', 'sadness', 'associated', 'loss', 'bereavement', 'tried', 'express', 'sorrow']
# ['sadness', 'associated', 'wrong', 'done', 'disappointment', 'drank', 'drown', 'sorrow', 'wrote', 'note', 'expressing', 'regret', 'rue', 'error', 'cost', 'game']
# ['sadness', 'expressed', 'weeping']
# ['emotional', 'moral', 'sensitivity', 'especially', 'relation', 'personal', 'principle', 'dignity', 'remark', 'hurt', 'feeling']
# ['sensitivity', 'leading', 'easy', 'irritation', 'upset']
# ['refined', 'sensitivity', 'pleasurable', 'painful', 'impression', 'cruelty', 'offended', 'sensibility']
# ['sentimental', 'feeling', 'loved', 'longer']
# ['extravagant', 'affected', 'feeling', 'emotion']
# ['feeling', 'shame', 'immoral', 'conscience', 'cruelty']
# ['shame', 'feel', 'inadequacy', 'guilt', 'made', 'public']
# ['shame', 'resulting', 'strong', 'dislike', 'action']
# ['feeling', 'sympathy', 'sorrow', 'misfortune', 'blind', 'often', 'object', 'pity']
# ['deep', 'awareness', 'sympathy', 'another', 'suffering']
# ['feeling', 'sympathetic', 'understanding']
# ['feeling', 'sympathy', 'felt', 'strong', 'concern', 'le', 'fortunate']
# ['understanding', 'entering', 'another', 'feeling']
# ['sympathy', 'arising', 'kind', 'heart']
# ['cheerful', 'agreeable', 'mood']
# ['angry', 'disagreeable', 'mood']
# ['annoyed', 'irritated', 'mood']
# ['mood', 'display', 'sullen', 'aloofness', 'withdrawal', 'stayed', 'home', 'sulk']
# ['absence', 'concern', 'welfare']
# ['unbiased', 'impartial', 'unconcern']
# ['living', 'extinct', 'member', 'family', 'hominidae', 'characterized', 'superior', 'intelligence', 'articulate', 'speech', 'erect', 'carriage']
# ['characteristic', 'humanity', 'human', 'nature']
# ['relating', 'person', 'experiment', 'wa', 'conducted', '6', 'monkey', '2', 'human', 'subject']
# ['human', 'form', 'attribute', 'opposed', 'animal', 'divine', 'body', 'kindness', 'frailty']
# ['human', 'wa', 'much', 'one', 'person']
# ['human', 'body', 'usually', 'including', 'clothing', 'weapon', 'wa', 'hidden', 'person']
# ['grammatical', 'category', 'used', 'classification', 'pronoun', 'possessive', 'determiner', 'verb', 'form', 'according', 'whether', 'indicate', 'speaker', 'addressee', 'third', 'party', 'stop', 'talking', 'person']
# ['experience', 'alive', 'course', 'human', 'event', 'activity', 'could', 'longer', 'cope', 'complexity', 'life']
# ['people', 'still', 'living', 'save', 'pity']
# ['condition', 'living', 'state', 'alive', 'life', 'hope', 'depends', 'many', 'chemical', 'physical', 'process']
# ['financial', 'mean', 'whereby', 'one', 'life', 'child', 'wa', 'expected', 'pay', 'keep', 'applied', 'state', 'support', 'could', 'longer', 'earn', 'livelihood']
# ['inhabit', 'live', 'inhabitant', 'people', 'lived', 'africa', 'million', 'year', 'ago', 'inhabited', 'island', 'deserted', 'kind', 'fish', 'dwells', 'near', 'bottom', 'ocean', 'deer', 'populating', 'wood']
# ['lead', 'certain', 'kind', 'life', 'live', 'style', 'frugally', 'war']
# ['continue', 'live', 'hardship', 'adversity', 'went', 'without', 'water', 'food', '3', 'day', 'superstition', 'survive', 'backwater', 'america', 'race', 'car', 'driver', 'lived', 'several', 'serious', 'accident', 'long', 'person', 'last']
# ['support', 'oneself', 'could', 'barely', 'exist', 'low', 'wage', 'live', '2000', 'month', 'new', 'york', 'city', 'many', 'people', 'world', 'subsist', '1', 'day']
# ['life', 'alive', 'great', 'leader', 'grandfather', 'lived', 'end', 'war']
# ['firsthand', 'knowledge', 'state', 'situation', 'emotion', 'sensation', 'know', 'feeling', 'ever', 'known', 'hunger', 'lived', 'kind', 'hell', 'wa', 'drug', 'addict', 'holocaust', 'survivor', 'nightmare', 'two', 'divorce']
# ['pursue', 'positive', 'satisfying', 'existence', 'must', 'accept', 'really', 'want', 'live']
# ['pertaining', 'living', 'person', 'within', 'memory']
# ['true', 'life', 'lifelike', 'living', 'image', 'mother']
# ['informal', 'absolute', 'living', 'doll', 'scared', 'daylight', 'beat', 'hell']
# ['still', 'existence', 'wollemi', 'pine', 'found', 'australia', 'surviving', 'specimen', 'conifer', 'thought', 'long', 'extinct', 'therefore', 'known', 'living', 'fossil', 'frontier', 'blockhouse', 'pennsylvania']
# ['still', 'active', 'use', 'living', 'language']
# ['used', 'mineral', 'stone', 'natural', 'state', 'place', 'mined', 'quarried', 'carved', 'living']
# ['extinct', 'specie', 'primitive', 'hominid', 'upright', 'stature', 'small', 'brain', 'homo', 'erectus', 'wa', 'formerly', 'called', 'pithecanthropus']
# ['extinct', 'specie', 'upright', 'east', 'african', 'hominid', 'advanced', 'humanlike', 'characteristic']
# ['surviving', 'hominid', 'specie', 'modern', 'man', 'belongs', 'bipedal', 'primate', 'language', 'ability', 'make', 'use', 'complex', 'tool', 'brain', 'volume', 'least', '1400', 'cc']
# ['extinct', 'primitive', 'hominid', 'late', 'pleistocene', 'java', 'formerly', 'javanthropus']
# ['extinct', 'robust', 'human', 'middle', 'paleolithic', 'europe', 'western', 'asia']
# ['primitive', 'hominid', 'resembling', 'neanderthal', 'man', 'living', 'africa']
# ['living', 'human', 'inhabitant', 'earth', 'world', 'love', 'lover', 'always', 'used', 'humankind', 'mankind', 'seemed', 'slight', 'woman']
# ['person', 'abates', 'nuisance']
# ['person', 'abjures']
# ['person', 'loathsome', 'disgusting']
# ['person', 'refrain', 'drinking', 'intoxicating', 'beverage']
# ['person', 'record', 'success', 'son', 'would', 'never', 'achiever', 'father', 'wa', 'winner', 'need', 'apply', 'want', 'dress', 'like']
# ['person', 'acquainted', 'trouble', 'remembering', 'name', 'acquaintance', 'friend', 'family']
# ['person', 'acquires', 'usually', 'permanently']
# ['person', 'participating', 'member', 'organization', 'club', 'issue', 'list', 'active', 'retiree']
# ['person', 'act', 'get', 'thing', 'done', 'principal', 'actor', 'affair', 'want', 'doer', 'miracle', 'worker']
# ['person', 'study', 'settle', 'conflict', 'dispute']
# ['person', 'admires', 'esteem', 'respect', 'approves']
# ['child', 'adopted']
# ['fully', 'developed', 'person', 'maturity', 'onward']
# ['person', 'enjoys', 'taking', 'risk']
# ['offer', 'opposition']
# ['receives', 'advice']
# ['person', 'pleads', 'cause', 'propounds', 'idea']
# ['person', 'make', 'affidavit']
# ['native', 'inhabitant', 'africa']
# ['doubtful', 'noncommittal']
# ['pursues', 'study', 'sport', 'pastime']
# ['member', 'people', 'living', 'north', 'south', 'america', 'european', 'arrived']
# ['person', 'lived', 'ancient', 'time']
# ['person', 'unusual']
# ['person', 'opposed', 'united', 'state', 'policy']
# ['person', 'opposed', 'action', 'policy', 'practice', 'etc', 'anti', 'smelled', 'victory', 'long', 'battle']
# ['person', 'request', 'seek', 'assistance', 'employment', 'admission']
# ['person', 'appointed', 'job', 'position']
# ['person', 'fully', 'aware', 'understands', 'appreciator', 'dilemma']
# ['person', 'seizes', 'arrest', 'especially', 'name', 'justice']
# ['astrology', 'person', 'born', 'sun', 'aquarius']
# ['person', 'archaizes']
# ['astrology', 'person', 'born', 'sun', 'aries']
# ['person', 'conceit', 'make', 'pretentious', 'claim', 'right', 'advantage', 'entitled', 'quality', 'doe', 'posse']
# ['person', 'property', 'assessed']
# ['person', 'suffering', 'asthma', 'chronic', 'asthmatic', 'painful', 'gasp', 'dying']
# ['usually', 'plural', 'person', 'exercise', 'administrative', 'control', 'authority', 'issued', 'curfew']
# ['person', 'taught']
# ['member', 'baby', 'boom', 'generation', '1950s', 'expanded', 'school', 'boomer']
# ['person', 'born', 'generation', 'following', 'baby', 'boom', 'birth', 'rate', 'fell', 'dramatically']
# ['person', 'side']
# ['person', 'doe', 'harm']
# ['person', 'whose', 'head', 'bald']
# ['person', 'refuse', 'comply']
# ['person', 'take', 'bath']
# ['person', 'diverts', 'suspicion', 'especially', 'woman', 'accompanies', 'male', 'homosexual', 'order', 'conceal', 'homosexuality']
# ['person', 'share', 'bed']
# ['person', 'suffered', 'death', 'loved', 'bereaved', 'always', 'need', 'taken', 'care']
# ['person', 'outstanding', 'excellent', 'top', 'could', 'beat', 'best']
# ['baby', 'born', 'offspring', 'overall', 'rate', 'incidence', 'syndrome', 'one', 'every', '800', 'birth']
# ['bite']
# ['person', 'dark', 'skin', 'come', 'africa', 'whose', 'ancestor', 'came']
# ['person', 'keep', 'update', 'blog']
# ['person', 'fair', 'skin', 'hair']
# ['person', 'dressed', 'blue', 'soldier', 'sailor']
# ['doe', 'special', 'exercise', 'develop', 'brawny', 'musculature']
# ['person', 'plant', 'bomb']
# ['person', 'dark', 'brown', 'hair']
# ['fight', 'bull']
# ['person', 'thing', 'break', 'overpowers', 'dam', 'buster', 'sanction', 'crime']
# ['astrology', 'person', 'born', 'sun', 'cancer']
# ['considered', 'office', 'prize', 'honor', 'etc']
# ['person', 'invests', 'capital', 'business', 'especially', 'large']
# ['astrology', 'person', 'born', 'sun', 'capricorn']
# ['person', 'capture', 'hold', 'people', 'animal']
# ['person', 'requiring', 'professional', 'service', 'typical', 'case', 'wa', 'suburban', 'housewife', 'described', 'marriage', 'counselor']
# ['person', 'responsible', 'receiving', 'payment', 'good', 'service', 'shop', 'restaurant']
# ['person', 'celebrating']
# ['censure', 'condemns']
# ['changeable', 'inconstant', 'person']
# ['person', 'change', 'inveterate', 'changer', 'menu']
# ['person', 'charm', 'usually', 'personal', 'attractiveness']
# ['immature', 'childish', 'person', 'remained', 'child', 'practical', 'matter', 'long', 'lived', 'stop', 'baby']
# ['yiddish', 'person', 'characterized', 'chutzpa']
# ['person', 'close', 'whoever', 'closer', 'turn', 'light', 'lock']
# ['person', 'poor', 'motor', 'coordination']
# ['person', 'collect', 'thing']
# ['person', 'unable', 'distinguish', 'difference', 'hue']
# ['fight', 'fighting']
# ['person', 'hold', 'title']
# ['person', 'communicates']
# ['make', 'thing', 'complex']
# ['person', 'compulsive', 'disposition', 'feel', 'compelled', 'certain', 'thing']
# ['person', 'us', 'computer', 'work', 'entertainment', 'communication', 'business']
# ['person', 'devoted', 'contemplative', 'life']
# ['person', 'participates', 'competition']
# ['person', 'converted', 'another', 'religious', 'political', 'belief']
# ['copy', 'word', 'behavior', 'another']
# ['person', 'count', 'thing']
# ['attempt', 'prevent', 'terrorism']
# ['person', 'show', 'fear', 'timidity']
# ['person', 'crawl', 'creep', 'along', 'ground']
# ['person', 'grows', 'make', 'invents', 'thing']
# ['human', 'wight', 'archaic', 'term']
# ['person', 'money', 'owed', 'debtor', 'obligation', 'exists']
# ['unable', 'walk', 'normally', 'injury', 'disability', 'leg', 'back']
# ['person', 'participates', 'social', 'gathering', 'arranged', 'dancing', 'ball']
# ['longer', 'alive', 'wonder', 'dead', 'person', 'would', 'done']
# ['person', 'severe', 'auditory', 'impairment']
# ['person', 'lower', 'quality', 'character', 'value', 'adding', 'cheaper', 'metal', 'coin']
# ['person', 'owes', 'creditor', 'obligation', 'paying', 'debt']
# ['person', 'defecates']
# ['person', 'delay', 'put', 'later', 'cause', 'late']
# ['person', 'give', 'transfer', 'money', 'good']
# ['person', 'make', 'demand']
# ['person', 'diet']
# ['person', 'differentiates']
# ['person', 'remove', 'tangle', 'take', 'tangled', 'state']
# ['person', 'dispute', 'good', 'enjoys', 'controversy']
# ['person', 'dissent', 'established', 'policy']
# ['person', 'separate', 'part', 'group']
# ['person', 'necessarily', 'spouse', 'cohabit', 'share', 'long-term', 'sexual', 'relationship']
# ['closely', 'resembles', 'famous', 'person', 'especially', 'actor', 'could', 'gingrich', 'double', 'image', 'mother']
# ['person', 'dress', 'particular', 'way', 'elegant', 'dresser', 'meticulous']
# ['person', 'dribble', 'baby', 'dribbler', 'need', 'bib']
# ['person', 'take', 'drug']
# ['person', 'dyslexia']
# ['person', 'thin', 'body']
# ['one', 'brings', 'result', 'event', 'accomplishes', 'purpose']
# ['person', 'lived', 'reign', 'elizabeth', 'william', 'shakespeare', 'wa', 'elizabethan']
# ['person', 'subject', 'strong', 'state', 'emotion']
# ['heavy', 'person', 'soft', 'rounded', 'body']
# ['person', 'us', 'scientific', 'knowledge', 'solve', 'practical', 'problem']
# ['person', 'delight', 'using', 'experiencing']
# ['person', 'enrolls', 'enrolled', 'class', 'course', 'study']
# ['person', 'try', 'please', 'amuse']
# ['person', 'member', 'ethnic', 'group']
# ['person', 'enjoys', 'testing', 'innovative', 'idea', 'wa', 'experimenter', 'new', 'form', 'poetry']
# ['person', 'special', 'knowledge', 'ability', 'performs', 'skillfully']
# ['travel', 'little', 'known', 'region', 'especially', 'scientific', 'purpose']
# ['psychology', 'person', 'concerned', 'practical', 'reality', 'inner', 'thought', 'feeling']
# ['part', 'person', 'used', 'refer', 'looked', 'roomful', 'face', 'returned', 'work', 'met', 'many', 'new']
# ['person', 'subscribes', 'variety', 'fad']
# ['person', 'fall', 'one', 'wa', 'safe', 'unable', 'save', 'faller', 'among', 'thief']
# ['person', 'fastens', 'make', 'fast', 'found', 'door', 'fastened', 'wondered', 'fastener', 'wa']
# ['person', 'belongs', 'sex', 'baby']
# ['person', 'hold', 'asset', 'trust', 'beneficiary', 'illegal', 'fiduciary', 'misappropriate', 'money', 'personal', 'gain']
# ['one', 'first-rate']
# ['person', 'accepts', 'leadership', 'another']
# ['acting', 'freely', 'even', 'irresponsibly']
# ['person', 'know', 'well', 'regard', 'affection', 'trust', 'wa', 'best', 'friend', 'university']
# ['flees', 'uncongenial', 'situation', 'fugitive', 'sweatshop']
# ['person', 'gain', 'weight']
# ['person', 'gain', 'advantage', 'profit', 'wa', 'clearly', 'gainer', 'exchange']
# ['person', 'wager', 'money', 'outcome', 'game', 'sporting', 'event']
# ['control', 'access', 'many', 'gatekeeper', 'field', 'officer', 'chief']
# ['person', 'gather', 'society', 'hunter', 'gatherer']
# ['astrology', 'person', 'born', 'sun', 'gemini']
# ['person', 'member', 'one', 'religion', 'used', 'sense', 'mormon', 'hindu']
# ['person', 'side']
# ['person', 'good', 'people']
# ['person', 'grant', 'give']
# ['person', 'greets', 'newcomer', 'met', 'smiling', 'greeter']
# ['person', 'grin']
# ['person', 'groan']
# ['person', 'grunt']
# ['person', 'guess']
# ['person', 'condition', 'markedly', 'restricts', 'ability', 'function', 'physically', 'mentally', 'socially']
# ['person', 'hate']
# ['heterosexual', 'person', 'sexual', 'orientation', 'opposite', 'sex']
# ['practice', 'homosexuality', 'sexual', 'attraction', 'person', 'sex']
# ['tiny', 'fully', 'formed', 'individual', 'according', 'discredited', 'theory', 'preformation', 'supposed', 'present', 'sperm', 'cell']
# ['expectation', 'centered', 'wa', 'best', 'hope', 'victory']
# ['person', 'hope', 'avid', 'hoper', 'could', 'expect', 'team', 'win']
# ['person', 'crouch', 'low', 'huddler', 'wind']
# ['person', 'hug']
# ['person', 'immune', 'particular', 'infection']
# ['person', 'pursues', 'independent', 'thought', 'action']
# ['person', 'inhabits', 'particular', 'place']
# ['person', 'lack', 'knowledge', 'evil']
# ['person', 'whose', 'interest', 'protected', 'insurance', 'policy', 'contract', 'indemnifies', 'loss', 'property', 'life', 'health', 'etc']
# ['person', 'us', 'mind', 'creatively']
# ['us', 'art', 'represent', 'painting', 'reveal', 'sensitive', 'interpreter', 'nature', 'wa', 'famous', 'shakespearean', 'role']
# ['psychology', 'person', 'tends', 'shrink', 'social', 'contact', 'become', 'preoccupied', 'thought']
# ['member', 'indo-european', 'people', 'widely', 'scattered', 'throughout', 'northwest', 'indian', 'subcontinent', 'consisting', 'muslim', 'hindu', 'sikh']
# ['person', 'belonging', 'worldwide', 'group', 'claiming', 'descent', 'jacob', 'converted', 'connected', 'cultural', 'religious', 'tie']
# ['person', 'brilliant', 'precious', 'piece', 'jewelry']
# ['person', 'jump', 'jumper', 'neared', 'ground', 'lost', 'control', 'parachute', 'opened']
# ['younger', 'two', 'person', 'year', 'junior']
# ['young', 'person', 'fully', 'developed']
# ['cause', 'death', 'person', 'animal']
# ['person', 'unusual', 'sexual', 'taste']
# ['person', 'kneeling', 'position']
# ['person', 'knock', 'seeking', 'gain', 'admittance', 'open', 'door', 'see', 'knocker']
# ['person', 'know', 'apprehends']
# ['person', 'greater', 'average', 'size']
# ['person', 'member', 'people', 'whose', 'language', 'derived', 'latin']
# ['person', 'laughing', 'laugh', 'easily']
# ['person', 'rule', 'guide', 'inspires']
# ['especially', 'child', 'learns', 'teacher', 'take', 'knowledge', 'belief']
# ['person', 'us', 'left', 'hand', 'greater', 'skill', 'right', 'pitcher', 'wa', 'southpaw']
# ['astrology', 'person', 'born', 'sun', 'leo']
# ['astrology', 'person', 'born', 'sun', 'libra']
# ['living', 'person', 'heroism', 'saved', 'life']
# ['frequent', 'target', 'negative', 'reaction', 'serf', 'distract', 'attention', 'another']
# ['person', 'speaks', 'one', 'language']
# ['person', 'read', 'write']
# ['person', 'special', 'life', 'style', 'high', 'liver']
# ['person', 'strong', 'desire', 'longer', 'money', 'thirster', 'blood', 'yearner', 'knowledge']
# ['person', 'expected', 'perform', 'particular', 'task', 'control', 'dangerous']
# ['person', 'love', 'usually', 'member', 'family']
# ['person', 'love', 'loved']
# ['efficient', 'person', 'boxer', 'wa', 'magnificent', 'fighting', 'machine']
# ['person', 'mail']
# ['person', 'discontented', 'disgusted']
# ['person', 'belongs', 'sex', 'baby']
# ['generic', 'use', 'word', 'refer', 'human', 'wa', 'every', 'man']
# ['single', 'individual', 'every', 'man', 'jack']
# ['person', 'handle', 'thing', 'manually']
# ['person', 'married', 'invited', 'several', 'young']
# ['person', 'practice', 'masturbation']
# ['person', 'make', 'measurement']
# ['person', 'well-developed', 'muscular', 'body']
# ['person', 'mixed', 'racial', 'ancestry', 'especially', 'european', 'native', 'american']
# ['neither', 'highbrow', 'lowbrow']
# ['person', 'claim', 'alleged', 'perform', 'miracle']
# ['person', 'hate', 'marriage']
# ['person', 'whose', 'ancestor', 'belonged', 'two', 'race']
# ['contemporary', 'person']
# ['person', 'receives', 'invests', 'pay', 'money']
# ['person', 'know', 'one', 'language']
# ['person', 'care', 'need', 'especially', 'overprotective', 'interfering', 'way']
# ['person', 'quiet', 'timid']
# ['person', 'mutilates', 'destroys', 'disfigures', 'cripple']
# ['person', 'give', 'name', 'owner', 'usually', 'namer', 'boat']
# ['person', 'name', 'another']
# ['person', 'owes', 'allegiance', 'nation', 'monarch', 'duty', 'subject']
# ['indigenous', 'person', 'wa', 'born', 'particular', 'place', 'art', 'native', 'northwest', 'coast', 'canadian', 'government', 'scrapped', 'plan', 'tax', 'grant', 'aboriginal', 'college', 'student']
# ['person', 'born', 'particular', 'place', 'country', 'native', 'brazil']
# ['person', 'neglectful', 'give', 'little', 'attention', 'respect', 'people', 'responsibility', 'tried', 'vainly', 'impress', 'neglecter']
# ['person', 'life', 'located', 'near', 'another']
# ['one', 'doe', 'side', 'party', 'war', 'dispute']
# ['person', 'easily', 'classified', 'interesting']
# ['person', 'member']
# ['person', 'doe', 'participate']
# ['person', 'nonpartisan']
# ['person', 'regarded', 'nonexistent', 'right', 'whose', 'existence', 'systematically', 'ignored', 'especially', 'ideological', 'political', 'reason', 'former', 'senator', 'treated', 'nonperson', 'administration', 'george', 'orwell', 'predicted', 'dissident', 'would', 'unperson']
# ['person', 'doe', 'manifest', 'devotion', 'deity']
# ['doe', 'live', 'particular', 'place', 'described', 'admiring', 'nonresident', 'green', 'pleasant', 'land']
# ['person', 'doe', 'smoke', 'tobacco']
# ['person', 'doe', 'nothing']
# ['naked', 'person']
# ['person', 'treat', 'carefully', 'great', 'nurser', 'penny']
# ['believer', 'occultism', 'versed', 'occult', 'art']
# ['person', 'disposed', 'take', 'favorable', 'view', 'thing']
# ['lack', 'support', 'care', 'supervision']
# ['person', 'refuse', 'face', 'reality', 'recognize', 'truth', 'reference', 'popular', 'notion', 'ostrich', 'hide', 'danger', 'burying', 'head', 'sand']
# ['person', 'ousts', 'supplants', 'else']
# ['person', 'belonging', 'caste']
# ['person', 'spends', 'time', 'outdoors', 'e.g.', 'hunting', 'fishing']
# ['person', 'owns', 'searching', 'owner', 'car', 'friendly', 'smile']
# ['pampers', 'spoil', 'excessive', 'indulgence']
# ['person', 'participates', 'open', 'sexual', 'activity', 'many', 'kind']
# ['person', 'pardon', 'forgives', 'excuse', 'fault', 'offense']
# ['person', 'member', 'partnership']
# ['person', 'involved', 'legal', 'proceeding', 'party', 'first', 'part']
# ['person', 'pass', 'member', 'different', 'ethnic', 'racial', 'group']
# ['person', 'equal', 'standing', 'another', 'group']
# ['person', 'becomes', 'aware', 'thing', 'event', 'sens']
# ['person', 'situated', 'perch']
# ['formal', 'non-european', 'non-white', 'person']
# ['another', 'word', 'person', 'meriting', 'identification', 'strange', 'personage', 'appeared', 'door']
# ['person', 'represents', 'abstract', 'quality', 'personification', 'optimism']
# ['person', 'perspires']
# ['wise', 'person', 'calm', 'rational', 'life', 'reason', 'equanimity']
# ['person', 'chooses', 'selects']
# ['astrology', 'person', 'born', 'sun', 'pisces']
# ['person', 'urinates']
# ['person', 'make', 'plan']
# ['person', 'pursues', 'number', 'different', 'social', 'sexual', 'partner', 'simultaneously']
# ['behaves', 'manner', 'calculated', 'impress', 'mislead']
# ['applies', 'scatter', 'powder']
# ['person', 'go', 'announces', 'coming', 'another']
# ['keep', 'safe', 'harm', 'danger']
# ['person', 'belongs', 'early', 'stage', 'civilization']
# ['person', 'immediately', 'affected', 'concerned', 'action']
# ['person', 'employed', 'establish', 'promote', 'favorable', 'relationship', 'public']
# ['person', 'pursues', 'plan', 'goal', 'pursuer', 'truth']
# ['person', 'regarded', 'easygoing', 'agreeable']
# ['unspecified', 'person', 'dropped', 'word', 'right', 'quarter']
# ['person', 'give', 'easily']
# ['person', 'radical', 'idea', 'opinion']
# ['person', 'accepts', 'world', 'literally', 'deal', 'accordingly']
# ['person', 'corrects', 'set', 'right', 'rectifier', 'prejudice']
# ['red', 'hair']
# ['person', 'formally', 'entered', 'along', 'register', 'obtains', 'certain', 'right', 'thereby']
# ['person', 'related', 'blood', 'marriage', 'police', 'searching', 'relative', 'deceased', 'distant', 'relation', 'back', 'new', 'jersey']
# ['person', 'reduces', 'intensity', 'e.g.', 'fear', 'calm', 'pacifies', 'reliever', 'anxiety', 'allayer']
# ['person', 'manifest', 'devotion', 'deity']
# ['person', 'repeat', 'audience', 'consisted', 'largely', 'repeater', 'seen', 'movie', 'many', 'time']
# ['save', 'danger', 'violence']
# ['person', 'rest']
# ['person', 'directs', 'restrains']
# ['person', 'return', 'lengthy', 'absence']
# ['person', 'posse', 'great', 'material', 'wealth']
# ['person', 'us', 'right', 'hand', 'skillfully', 'left']
# ['person', 'rise', 'especially', 'bed', 'usually', 'late', 'riser']
# ['person', 'romp', 'frolic']
# ['brachycephalic', 'person']
# ['person', 'rule', 'command', 'swayer', 'universe']
# ['person', 'rush', 'hurry', 'act', 'precipitously']
# ['astrology', 'person', 'born', 'sun', 'sagittarius']
# ['person', 'advanced', 'knowledge', 'one', 'science']
# ['astrology', 'person', 'born', 'sun', 'scorpio']
# ['person', 'scratch', 'relieve', 'itch']
# ['person', 'second-rate', 'ability', 'value', 'team', 'aging', 'second-rater', 'shone', 'among', 'mediocrity', 'surrounded']
# ['person', 'seed', 'cloud']
# ['making', 'search', 'inquiry', 'seeker', 'truth']
# ['segregated']
# ['person', 'considered', 'unique', 'individual', 'one', 'self']
# ['person', 'enjoys', 'sensuality']
# ['indulges', 'excessive', 'sentimentality']
# ['person', 'regarded', 'simply', 'object', 'sexual', 'gratification']
# ['person', 'especially', 'celebrity', 'well-known', 'sexual', 'attractiveness']
# ['person', 'wields', 'power', 'influence', 'shaker', 'traditional', 'belief', 'mover', 'business', 'world']
# ['person', 'skilled', 'making', 'effective', 'presentation']
# ['sign', 'bound', 'document']
# ['person', 'lacking', 'intelligence', 'common', 'sense']
# ['person', 'least', 'six', 'foot', 'tall']
# ['person', 'slip', 'slide', 'loss', 'traction']
# ['member', 'people', 'eastern', 'europe', 'asian', 'russia', 'speak', 'slavonic', 'language']
# ['person', 'owned']
# ['entirely', 'dominated', 'influence', 'person', 'slave', 'fashion', 'cocaine', 'mother', 'wa', 'abject']
# ['sleepy', 'person']
# ['person', 'slouch', 'drooping', 'carriage']
# ['person', 'average', 'size']
# ['person', 'smash']
# ['person', 'smile']
# ['person', 'sneeze']
# ['person', 'sniff']
# ['person', 'breathes', 'audibly', 'congested', 'nose']
# ['person', 'snuff', 'candle']
# ['person', 'breathes', 'noisily', 'nose', 'blocked', 'mucus']
# ['person', 'take', 'part', 'social', 'activity']
# ['person', 'particular', 'character', 'nature', 'sort', 'good']
# ['person', 'whose', 'reaction', 'serve', 'indication', 'acceptability', 'would', 'use', 'newspaperman', 'sounding', 'board', 'policy']
# ['inscrutable', 'person', 'keep', 'thought', 'intention', 'secret']
# ['person', 'spit', 'ejects', 'saliva', 'phlegm', 'mouth']
# ['person', 'known', 'way', 'behaves', 'teased', 'defeated', 'subjected', 'trying', 'circumstance', 'good', 'sport', 'poor']
# ['person', 'sprawl', 'sprawler', 'need', 'bed']
# ['person', 'reject', 'contempt', 'wa', 'known', 'spurner', 'suitor', 'rule']
# ['person', 'strabismus']
# ['person', 'stifle', 'smother', 'suppresses', 'real', 'conversation', 'stifler', 'see', 'yawn', 'smotherer', 'time', 'stop']
# ['person', 'whose', 'body', 'marked', 'religious', 'stigma', 'mark', 'resembling', 'wound', 'crucified', 'christ']
# ['person', 'carry', 'head', 'shoulder', 'habitually', 'bent', 'forward']
# ['individual', 'one', 'acquainted']
# ['person', 'struggle', 'difficulty', 'great', 'effort']
# ['person', 'subjected', 'experimental', 'observational', 'procedure', 'object', 'investigation', 'subject', 'selected', 'randomly', 'case', 'studied', 'drawn', 'two', 'different', 'community']
# ['person', 'serving', 'apparent', 'function', 'reducing', 'staff', 'difficult', 'employee', 'include', 'supernumerary']
# ['person', 'yield', 'surrender']
# ['try', 'insure', 'personal', 'survival', 'group', 'nation']
# ['one', 'outlives', 'another', 'left', 'farm', 'survivor']
# ['suspicion']
# ['assigns', 'label', 'grammatical', 'constituent', 'textual', 'matter']
# ['appends', 'join', 'one', 'thing', 'another', 'theory', 'wa', 'simply', 'added', 'anonymous', 'tagger']
# ['person', 'strike', 'surface', 'lightly', 'usually', 'repeatedly', 'finger', 'tapper', 'irritated']
# ['astrology', 'person', 'born', 'sun', 'taurus']
# ['person', 'tempts', 'satan', 'great', 'tempter', 'mankind']
# ['person', 'serf', 'specified', 'term', 'many', 'fourth', 'termer', 'senate']
# ['person', 'inspires', 'fear', 'dread', 'wa', 'terror', 'neighborhood']
# ['person', 'make']
# ['person', 'unusually', 'thin', 'scrawny']
# ['one', 'third-rate', 'distinctly', 'inferior']
# ['project', 'especially', 'rapid', 'motion', 'arm']
# ['fierce', 'audacious', 'person', 'tiger', 'tennis', 'court', 'aroused']
# ['person', 'belongs', 'clan', 'tribe', 'totem']
# ['person', 'cause', 'allows', 'part', 'body', 'come', 'contact']
# ['transfer', 'transferred', 'one', 'position', 'another', 'best', 'student', 'wa', 'lsu']
# ['person', 'whose', 'sexual', 'identification', 'entirely', 'opposite', 'sex']
# ['adopts', 'dress', 'manner', 'sexual', 'role', 'opposite', 'sex']
# ['person', 'change', 'location']
# ['one', 'try']
# ['one', 'two', 'person', 'swing', 'rope', 'jumper', 'skip', 'game', 'jump']
# ['person', 'exercise', 'power', 'cruel', 'way', 'father', 'wa', 'tyrant']
# ['person', 'unfastens', 'unwraps', 'open', 'child', 'talented', 'undoer', 'shoelace']
# ['person', 'suffers', 'misfortune']
# ['person', 'lack', 'technical', 'training']
# ['person', 'reason', 'wanted', 'welcome']
# ['person', 'make', 'use', 'thing', 'us', 'employ']
# ['person', 'disappears']
# ['person', 'tricked', 'swindled']
# ['person', 'lived', 'reign', 'victoria']
# ['astrology', 'person', 'born', 'sun', 'virgo']
# ['person', 'given', 'fanciful', 'speculation', 'enthusiasm', 'little', 'regard', 'actually', 'possible']
# ['inferior', 'vision']
# ['person', 'wait', 'awaits']
# ['person', 'awakes', 'early', 'waker']
# ['person', 'walk', 'without', 'appointment', 'emergency', 'room', 'wa', 'overrun', 'walk-in']
# ['person', 'want', 'need', 'owner', 'many', 'thing', 'needer', 'none']
# ['person', 'protection', 'custody', 'another']
# ['engaged', 'experienced', 'warfare']
# ['person', 'keep', 'devotional', 'vigil', 'sick', 'bed', 'dead', 'body']
# ['person', 'physically', 'weak', 'ineffectual']
# ['person', 'regarded', 'treacherous', 'sneaky']
# ['member', 'caucasoid', 'race']
# ['one', 'ca', "n't", 'stay', 'still', 'especially', 'child', 'toddler', 'wa', 'real', 'wiggler', 'plane', 'trip']
# ['person', 'wink']
# ['person', 'refrain', 'granting', 'withholder', 'payment']
# ['law', 'person', 'testifies', 'oath', 'court']
# ['person', 'work', 'specific', 'occupation', 'good', 'worker']
# ['person', 'absorbed', 'concern', 'interest', 'pleasure', 'present', 'world']
# ['person', 'yawn']
# ['pronoun', 'verb', 'used', 'refer', 'speaker', 'writer', 'language', 'occur']
# ['pronoun', 'verb', 'used', 'refer', 'person', 'addressed', 'language', 'occur']
# ['pronoun', 'verb', 'used', 'refer', 'speaker', 'addressee', 'language', 'occur']
# ['life', 'without', 'beginning', 'end']
# ['person', 'skin', 'regarded', 'life', 'tried', 'save']
# ['state', 'surviving', 'remaining', 'alive']
# ['thing', 'make', 'comfortable', 'ease', 'comfort', 'home']
# ['mean', 'maintenance', 'family', 'group']
# ['source', 'income', 'livelihood']
# ['minimal', 'marginal', 'resource', 'subsisting', 'social', 'security', 'provided', 'bare', 'subsistence']
# ['live', 'take', 'one', 'meal', 'room', 'old', 'boarding', 'house']
# ['live', 'tent', 'go', 'camping', 'summer', 'circus', 'tented', 'near', 'town', 'houseguest', 'camp', 'living', 'room']
# ['share', 'living', 'quarter', 'usually', 'said', 'people', 'married', 'live', 'together', 'couple']
# ['lodger', 'stay', 'temporarily', 'lodging', 'paris']
# ['live', 'located', 'neighbor', 'neighboring', 'house']
# ['inhabit', 'nest', 'usually', 'building', 'bird', 'nesting', 'outside', 'window', 'every', 'spring']
# ['live', 'certain', 'place', 'resides', 'princeton', 'occupies', 'two', 'room', 'top', 'floor']
# ['cause', 'great', 'population', 'town', 'new', 'jersey', 'becoming', 'overpopulated']
# ['furnish', 'people', 'plain', 'sparsely', 'populated']
# ['make', 'one', 'home', 'particular', 'place', 'community', 'may', 'parent', 'reside', 'florida']
# ['occupy', 'tenant']
# ['lead', 'bachelor', 'existence']
# ['live', 'like', 'buccaneer']
# ['live', 'bush', 'fugitive', 'guerilla']
# ['choose', 'simpler', 'life', 'style', 'questioning', 'personal', 'career', 'satisfaction', 'goal', '3', 'decade', 'politics', 'cashed', 'moved', 'polynesia']
# ['live', 'life', 'pleasure', 'especially', 'respect', 'alcoholic', 'consumption']
# ['live', 'day', 'hardship', 'eked', 'year', 'great', 'poverty']
# ['live', 'one', 'life', 'specified', 'environment', 'move', 'certain', 'circle']
# ['live', 'like', 'pig', 'squalor']
# ['live', 'lively', 'modern', 'relaxed', 'style', 'woodstock', 'generation', 'attempted', 'swing', 'freely']
# ['live', 'annul', 'previous', 'behavior', 'never']
# ['lead', 'passive', 'existence', 'without', 'using', 'one', 'body', 'mind']
# ['indulge', 'carefree', 'voluptuous', 'way', 'life']
# ['live', 'one', 'life', 'end']
# ['survive', 'season', 'plant']
# ['resist', 'withstand', 'wear', 'criticism', 'etc', 'shoe', 'wo', "n't", 'hold', 'theory', 'water']
# ['alive', 'every', 'creature', 'breathes']
# ['live', 'unhurriedly', 'irresponsibly', 'freely', 'son', 'drifted', 'around', 'year', 'california', 'going', 'law', 'school']
# ['experience', 'often', 'imagination', 'relived', 'horror', 'war']
# ['experience', 'briefly', 'ex-slave', 'tasted', 'freedom', 'shortly', 'died']
# ['fossil', 'remains', 'found', 'java', 'formerly', 'called', 'pithecanthropus', 'erectus']
# ['fossil', 'found', 'near', 'beijing', 'china', 'lost', 'world', 'war', 'ii']
# ['possible', 'early', 'homo', 'sapiens', 'represented', 'cranium', 'found', 'transvaal', 'formerly', 'considered', 'separate', 'specie']
# ['extinct', 'human', 'upper', 'paleolithic', 'europe']
# ['subspecies', 'homo', 'sapiens', 'includes', 'modern', 'race']
# ['early', 'man', 'late', 'pleistocene', 'skull', 'resembles', 'neanderthal', 'smaller', 'cranial', 'capacity', 'found', 'java']
# ['strong', 'emotion', 'feeling', 'oriented', 'toward', 'real', 'supposed', 'grievance']
# ['state', 'angry']
# ['belligerence', 'aroused', 'real', 'supposed', 'wrong', 'personified', 'one', 'deadly', 'sin']
# ['make', 'angry', 'news', 'angered']
# ['become', 'angry', 'anger', 'easily']
# ['experiencing', 'affective', 'emotional', 'state', 'feeling', 'euphoria', 'terrible', 'guilt', 'disliked', 'wa', 'mutual']
# ['vague', 'idea', 'confidence', 'placed', 'impression', 'wa', 'favorable', 'feeling', 'crisis', 'strengthened', 'belief', 'sincerity', 'lying']
# ['general', 'atmosphere', 'place', 'situation', 'effect', 'people', 'feel', 'city', 'excited', 'clergyman', 'improved', 'tone', 'meeting', 'smell', 'treason']
# ['physical', 'sensation', 'experience', 'queasy', 'feeling', 'strange', 'leg', 'lost', 'arm']
# ...
# ['loose', 'soft', 'material', 'make', 'large', 'part', 'land', 'surface', 'dug', 'earth', 'outside', 'church']
# ['various', 'elastic', 'material', 'resemble', 'rubber', 'resume', 'original', 'shape', 'deforming', 'force', 'removed']
# ['slender', 'greatly', 'elongated', 'substance', 'capable', 'spun', 'yarn']
# ['material', 'fill', 'space', 'container', 'wa', 'enough', 'trench']
# ['small', 'loosely', 'aggregated', 'mass', 'flocculent', 'material', 'suspended', 'precipitated', 'liquid']
# ['light', 'downy', 'material']
# ['lightweight', 'material', 'cellular', 'form', 'made', 'introducing', 'gas', 'bubble', 'manufacture']
# ['abbreviation', 'hazardous', 'material', 'used', 'warning', 'sign', 'hazmat', 'tunnel']
# ['material', 'homogenized', 'especially', 'tissue', 'ground', 'mixed', 'liver', 'homogenate']
# ['material', 'high', 'humic', 'acid']
# ['material', 'impregnated', 'impregnation', 'whatever', 'wa', 'turned', 'rock', 'blue']
# ['material', 'glass', 'porcelain', 'negligible', 'electrical', 'thermal', 'conductivity']
# ['solid', 'homogeneous', 'inorganic', 'substance', 'occurring', 'nature', 'definite', 'chemical', 'composition']
# ['material', 'used', 'especially', 'protect']
# ['material', 'made', 'cellulose', 'pulp', 'derived', 'mainly', 'wood', 'rag', 'certain', 'grass']
# ['small', 'discrete', 'mass', 'solid', 'liquid', 'matter', 'remains', 'individually', 'dispersed', 'gas', 'emission', 'usually', 'considered', 'atmospheric', 'pollutant']
# ['material', 'derived', 'plant']
# ['substance', 'another', 'formed', 'especially', 'metabolic', 'reaction']
# ['material', 'radioactive']
# ['material', 'suitable', 'manufacture', 'use', 'finishing']
# ['natural', 'outer', 'covering', 'food', 'usually', 'removed', 'eating']
# ['material', 'consisting', 'aggregate', 'mineral', 'like', 'making', 'earth', 'crust', 'mountain', 'solid', 'rock', 'stone', 'abundant', 'new', 'england', 'many', 'quarry']
# ['substance', 'used', 'seal', 'joint', 'fill', 'crack', 'porous', 'surface']
# ['material', 'capable', 'taken', 'another', 'substance', 'either', 'absorption', 'adsorption']
# ['material', 'sorb', 'another', 'substance', 'i.e', 'capacity', 'tendency', 'take', 'either', 'absorption', 'adsorption']
# ['material', 'used', 'thicken', 'starch', 'cooking', 'thickening']
# ['black', 'colored', 'powder', 'used', 'printer', 'develop', 'xerographic', 'image']
# ['material', 'property', 'admitting', 'light', 'diffusely', 'partly', 'transparent']
# ['material', 'removed', 'cut', 'made', 'underneath']
# ['white', 'cheeselike', 'protective', 'material', 'cover', 'skin', 'fetus']
# ['small', 'mass', 'soft', 'material', 'used', 'wad', 'cotton', 'wipe', 'counter']
# ['material', 'unused', 'rejected', 'worthless', 'unwanted', 'collect', 'waste', 'week', 'much', 'carried', 'sewer']
# ['material', 'suitable', 'journalistic', 'account', 'catastrophe', 'make', 'good', 'copy']
# ['old', 'material', 'slightly', 'reworked', 'used', 'merely', 'dull', 'rehash', 'first', 'novel']
# ['fabric', 'woven', 'goat', 'hair', 'camel']
# ['synthetic', 'fabric']
# ['trademark', 'loosely', 'woven', 'cotton', 'fabric', 'used', 'make', 'shirt', 'underwear']
# ['thin', 'glossy', 'fabric', 'made', 'wool', 'lama', 'pacos', 'rayon', 'cotton', 'imitation']
# ['bright', 'green', 'fabric', 'napped', 'resemble', 'felt', 'used', 'cover', 'gaming', 'table']
# ['cloth', 'woven', 'two', 'thread', 'interlaced', 'suggest', 'weave', 'basket']
# ['dyed', 'fabric', 'removable', 'wax', 'used', 'dye', 'wanted']
# ['thin', 'plain-weave', 'cotton', 'linen', 'fabric', 'used', 'shirt', 'dress']
# ['material', 'belt', 'made']
# ['twilled', 'fabric', 'used', 'dress', 'warp', 'silk', 'weft', 'worsted', 'black', 'bombazine', 'frequently', 'mourning', 'garment']
# ['fabric', 'uneven', 'yarn', 'knobby', 'effect']
# ['densely', 'textured', 'woolen', 'fabric', 'lustrous', 'finish']
# ['closely', 'woven', 'silk', 'synthetic', 'fabric', 'narrow', 'crosswise', 'rib']
# ['thick', 'heavy', 'expensive', 'material', 'raised', 'pattern']
# ['coarse', 'cotton', 'fabric', 'stiffened', 'glue', 'used', 'bookbinding', 'stiffen', 'clothing']
# ['loosely', 'woven', 'fabric', 'used', 'flag', 'etc']
# ['coarse', 'cloth', 'bright', 'print']
# ['finely', 'woven', 'white', 'linen']
# ['soft', 'tan', 'cloth', 'made', 'hair', 'camel']
# ['fabric', 'asian', 'origin', 'originally', 'made', 'silk', 'camel', 'hair']
# ['fabric', 'dyed', 'splotch', 'green', 'brown', 'black', 'tan', 'intended', 'make', 'wearer', 'garment', 'made', 'hard', 'distinguish', 'background']
# ['umbrellalike', 'part', 'parachute', 'fill', 'air']
# ['heavy', 'closely', 'woven', 'fabric', 'used', 'clothing', 'chair', 'sail', 'tent']
# ['soft', 'fabric', 'made', 'wool', 'cashmere', 'goat']
# ['waterproof', 'waxed', 'cloth', 'used', 'shroud']
# ['soft', 'lightweight', 'fabric', 'usually', 'printed']
# ['lightweight', 'fabric', 'woven', 'white', 'thread', 'across', 'colored', 'warp']
# ['heavy', 'fabric', 'woven', 'chenille', 'cord', 'used', 'rug', 'bedspread']
# ['sheer', 'fabric', 'silk', 'rayon']
# ['coarse', 'twilled', 'cotton', 'fabric', 'frequently', 'used', 'uniform']
# ['brightly', 'printed', 'glazed', 'cotton', 'fabric']
# ['heavy', 'fabric', 'suitable', 'coat']
# ['fabric', 'delicate', 'transparent', 'resemble', 'web', 'spider']
# ['cut', 'pile', 'fabric', 'vertical', 'rib', 'usually', 'made', 'cotton']
# ['fabric', 'woven', 'cotton', 'fiber']
# ['stout', 'cotton', 'fabric', 'nap', 'one', 'side']
# ['soft', 'thin', 'light', 'fabric', 'crinkled', 'surface']
# ['unglazed', 'heavy', 'fabric', 'brightly', 'printed', 'used', 'slipcover', 'drapery']
# ['stiff', 'coarse', 'fabric', 'used', 'stiffen', 'hat', 'clothing']
# ['fabric', 'linen', 'cotton', 'silk', 'wool', 'reversible', 'pattern', 'woven']
# ['coarse', 'durable', 'twill-weave', 'cotton', 'fabric']
# ['fabric', 'covered', 'glittering', 'ornament', 'sequin', 'rhinestone']
# ['fabric', 'usually', 'cotton', 'linen', 'distinctive', 'woven', 'pattern', 'small', 'repeated', 'figure']
# ['strong', 'cotton', 'fabric', 'raised', 'pattern', 'used', 'bedcover', 'curtain']
# ['fine', 'smooth', 'soft', 'woolen', 'fabric']
# ['cloth', 'gracefully', 'draped', 'arranged', 'loose', 'fold']
# ['heavy', 'cotton', 'fabric', 'plain', 'weave', 'used', 'clothing', 'tent']
# ['coarse', 'heavy', 'woolen', 'fabric']
# ['fabric', 'made', 'yarn', 'containing', 'elastic', 'material']
# ['soft', 'cotton', 'worsted', 'fabric', 'open', 'mesh', 'used', 'curtain', 'clothing', 'etc']
# ['ribbed', 'woven', 'fabric', 'silk', 'rayon', 'cotton']
# ['fabric', 'made', 'compressed', 'matted', 'animal', 'fiber']
# ['leatherlike', 'material', 'made', 'compressing', 'layer', 'paper', 'cloth']
# ['soft', 'light', 'woolen', 'fabric', 'used', 'clothing']
# ['cotton', 'fabric', 'imitating', 'flannel']
# ['soft', 'bulky', 'fabric', 'deep', 'pile', 'used', 'chiefly', 'clothing']
# ['light', 'plain-weave', 'twill-weave', 'silk', 'silklike', 'fabric', 'usually', 'printed', 'design']
# ['heavy', 'woolen', 'fabric', 'long', 'nap']
# ['strong', 'cotton', 'linen', 'fabric', 'slight', 'nap']
# ['firm', 'durable', 'fabric', 'twill', 'weave']
# ['thin', 'silk', 'dress', 'material']
# ['clothing', 'fabric', 'plaid', 'weave']
# ['coarse', 'fabric', 'silk', 'mixed', 'wool', 'mohair', 'often', 'stiffened', 'gum']
# ['silk', 'silklike', 'fabric', 'crosswise', 'rib']
# ['cloth', 'woven', 'horsehair', 'camelhair', 'used', 'upholstery', 'stiffening', 'garment']
# ['twilled', 'fabric', 'herringbone', 'pattern']
# ['rough', 'loosely', 'woven', 'fabric', 'originally', 'made', 'yarn', 'wa', 'spun', 'home']
# ['loosely', 'woven', 'coarse', 'fabric', 'cotton', 'linen', 'used', 'clothing']
# ['fabric', 'made', 'fiber', 'taken', 'mane', 'tail', 'horse', 'used', 'upholstery']
# ['lightweight', 'cotton', 'cloth', 'smooth', 'slightly', 'stiff', 'finish', 'used', 'clothing', 'bandage']
# ['highly', 'figured', 'fabric', 'woven', 'jacquard', 'loom']
# ['coarse', 'homespun', 'cotton', 'cloth', 'made', 'india']
# ['sturdy', 'twilled', 'cloth', 'yellowish', 'brown', 'color', 'used', 'especially', 'military', 'uniform']
# ['fabric', 'made', 'knitting']
# ['delicate', 'decorative', 'fabric', 'woven', 'open', 'web', 'symmetrical', 'pattern']
# ['fabric', 'interwoven', 'thread', 'metal', 'wore', 'gold', 'lame', 'dress']
# ['fabric', 'made', 'look', 'like', 'leather']
# ['fabric', 'woven', 'fiber', 'flax', 'plant']
# ['rough', 'fabric', 'linen', 'warp', 'wool', 'cotton', 'woof']
# ['cotton', 'linen', 'fabric', 'nap', 'raised', 'one', 'side', 'used', 'dress', 'wound']
# ['fabric', 'woven', 'lisle', 'thread']
# ['heavy', 'woolen', 'cloth', 'heavily', 'napped', 'felted', 'often', 'plaid', 'design']
# ['lightweight', 'waterproof', 'usually', 'rubberized', 'fabric']
# ['light', 'patterned', 'cotton', 'cloth']
# ['strong', 'cotton', 'fabric', 'raised', 'pattern', 'used', 'bedspread']
# ['fabric', 'made', 'yarn', 'partly', 'entirely', 'metal']
# ['fabric', 'made', 'yarn', 'silky', 'hair', 'angora', 'goat']
# ['silk', 'fabric', 'wavy', 'surface', 'pattern']
# ['durable', 'cotton', 'fabric', 'velvety', 'nap']
# ['heavy', 'cloth', 'basket', 'weave']
# ['thick', 'velvety', 'synthetic', 'fabric', 'used', 'carpet', 'soft', 'upholstery']
# ['heavy', 'fabric', 'wool', 'cotton', 'used', 'mostly', 'upholstery', 'curtain']
# ['multicolored', 'woolen', 'fabric', 'woven', 'mixed', 'thread', '14th', '17th', 'century', 'england']
# ['gauze-like', 'fabric', 'silk', 'rayon']
# ['plain-woven', 'cotton', 'fabric']
# ['durable', 'fabric', 'formerly', 'loomed', 'hand', 'china', 'natural', 'cotton', 'yellowish', 'color']
# ['open', 'fabric', 'string', 'rope', 'wire', 'woven', 'together', 'regular', 'interval']
# ['fine', 'strong', 'sheer', 'silky', 'fabric', 'made', 'silk', 'rayon', 'nylon']
# ['synthetic', 'fabric']
# ['cloth', 'treated', 'one', 'side', 'drying', 'oil', 'synthetic', 'resin']
# ['cloth', 'olive-brown', 'color', 'used', 'military', 'uniform']
# ['fabric', 'made', 'silk', 'silklike', 'resembles', 'organdy']
# ['soft', 'wool', 'fabric', 'colorful', 'swirled', 'pattern', 'curved', 'shape']
# ['fabric', 'used', 'make', 'trouser']
# ['fabric', 'woven', 'fleck', 'light', 'dark']
# ['fine', 'closely', 'woven', 'cotton', 'fabric']
# ['fabric', 'chemically', 'processed', 'resist', 'wrinkle', 'hold', 'shape']
# ['separate', 'part', 'consisting', 'fabric']
# ['thick', 'blue', 'cloth', 'used', 'make', 'overcoat', 'coat', 'sailor', 'etc']
# ['fine', 'cloth', 'made', 'pineapple', 'fiber']
# ['fabric', 'thin', 'stripe']
# ['tightly', 'woven', 'fabric', 'raised', 'cord']
# ['fabric', 'nap', 'longer', 'softer', 'velvet']
# ['large', 'class', 'synthetic', 'fabric']
# ['soft', 'thin', 'cloth', 'woven', 'raw', 'silk', 'imitation']
# ['ribbed', 'fabric', 'used', 'clothing', 'upholstery']
# ['fabric', 'dyed', 'pattern', 'pressed', 'onto', 'usually', 'engraved', 'roller']
# ['material', 'used', 'making', 'quilt', 'quilted', 'fabric']
# ['synthetic', 'silklike', 'fabric']
# ['fabric', 'prominent', 'rounded', 'crosswise', 'rib']
# ['coarse', 'cloth', 'resembling', 'sacking']
# ['coarse', 'fabric', 'used', 'bag', 'sack']
# ['strong', 'fabric', 'cotton', 'canvas', 'used', 'making', 'sail', 'tent']
# ['heavy', 'silk', 'fabric', 'often', 'woven', 'silver', 'gold', 'thread', 'used', 'make', 'clothing', 'middle', 'age']
# ['cotton', 'fabric', 'satiny', 'finish']
# ['smooth', 'fabric', 'silk', 'rayon', 'glossy', 'face', 'dull', 'back']
# ['fabric', 'finish', 'resembling', 'satin', 'made', 'partly', 'wholly', 'cotton', 'synthetic', 'fiber']
# ['fabric', 'metal', 'plastic', 'mesh']
# ['firm', 'open-weave', 'fabric', 'used', 'curtain', 'theater']
# ['light', 'puckered', 'fabric', 'usually', 'striped']
# ['twilled', 'woolen', 'fabric']
# ['fabric', 'long', 'coarse', 'nap', 'bought', 'shag', 'rug']
# ['heavy', 'silk', 'fabric', 'rough', 'surface', 'cotton', 'imitation']
# ['smooth', 'crisp', 'fabric']
# ['fabric', 'bed', 'sheet', 'made']
# ['various', 'fabric', 'used', 'make', 'men', 'shirt']
# ['fabric', 'forming', 'tail', 'shirt']
# ['sturdy', 'twill-weave', 'cotton', 'fabric', 'used', 'pocket', 'lining']
# ['fabric', 'made', 'fine', 'thread', 'produced', 'certain', 'insect', 'larva']
# ['elastic', 'synthetic', 'fabric']
# ['soft', 'porous', 'fabric', 'especially', 'loose', 'honeycomb', 'weave']
# ['coarse', 'woolen', 'cloth', 'formerly', 'used', 'undergarment', 'usually', 'dyed', 'bright', 'red']
# ['fabric', 'made', 'resemble', 'suede', 'leather']
# ['fabric', 'used', 'suit']
# ['soft', 'woolen', 'fabric', 'used', 'especially', 'baby', 'clothes']
# ['crisp', 'smooth', 'lustrous', 'fabric']
# ['plain-woven', 'often', 'glazed', 'fabric', 'wool', 'cotton', 'used', 'especially', 'formerly', 'lining', 'garment', 'curtain']
# ['paperlike', 'cloth', 'made', 'south', 'pacific', 'pounding', 'tapa', 'bark']
# ['heavy', 'textile', 'woven', 'design', 'used', 'curtain', 'upholstery']
# ['cloth', 'crisscross', 'design']
# ['pile', 'fabric', 'usually', 'cotton', 'uncut', 'loop', 'side', 'used', 'make', 'bath', 'towel', 'robe']
# ['strong', 'fabric', 'used', 'mattress', 'pillow', 'cover']
# ['various', 'fabric', 'linen', 'cotton', 'used', 'make', 'towel']
# ['thick', 'woolen', 'fabric', 'used', 'clothing', 'originated', 'scotland']
# ['cloth', 'parallel', 'diagonal', 'line', 'rib']
# ['fabric', 'used', 'upholstering']
# ['nylon', 'fabric', 'used', 'fastening']
# ['heavy', 'fabric', 'resembles', 'velvet']
# ['silky', 'densely', 'piled', 'fabric', 'plain', 'back']
# ['usually', 'cotton', 'fabric', 'short', 'pile', 'imitating', 'velvet']
# ['soft', 'wool', 'fabric', 'made', 'fleece', 'vicuna']
# ['fabric', 'made', 'twilled', 'mixture', 'cotton', 'wool']
# ['light', 'semitransparent', 'fabric']
# ['fabric', 'treated', 'easily', 'washable', 'require', 'ironing']
# ['fabric', 'impervious', 'water']
# ['fabric', 'especially', 'process', 'woven']
# ['strong', 'fabric', 'woven', 'strip']
# ['strong', 'worsted', 'cotton', 'fabric', 'diagonal', 'rib']
# ['plain', 'twilled', 'fabric', 'wool', 'cotton', 'used', 'especially', 'warm', 'shirt', 'skirt', 'pajama']
# ['fabric', 'woven', 'metallic', 'wire']
# ['fabric', 'made', 'hair', 'sheep']
# ['woolen', 'fabric', 'hard', 'textured', 'surface', 'nap', 'woven', 'worsted', 'yarn', 'wore', 'suit']
# ['fabric', 'comprising', 'fitted', 'part', 'top', 'garment']
# ['material', 'used', 'make', 'package']
# ['material', 'making', 'rail', 'collectively']
# ['material', 'used', 'construct', 'roof']
# ['take', 'use', 'helped', 'office', 'supply']
# ['turn', 'one', 'advantage', 'environmentalist', 'lobby', 'made', 'hay', 'nuclear', 'plant', 'accident']
# ['use', 'one', 'advantage', 'play', 'client', 'emotion']
# ['profit', 'exploitatory', 'manner', 'feed', 'insecurity']
# ['exploit', 'maximal', 'profit', 'usually', 'sacrificing', 'quality', 'hotel', 'owner', 'commercializing', 'beach']
# ['exploit', 'power', 'harness', 'natural', 'force', 'resource']
# ['make', 'maximized', 'role']
# ['exploit', 'much', 'possible', 'milking', 'worth']
# ['get', 'earth', 'excavation', 'mine', 'ore', 'metal']
# ['exploit', 'excessively', 'overexploit', 'natural', 'resource']
# ['extract', 'stone', 'quarry', 'marble']
# ['apply', 'oneself', 'please', 'homework']
# ['dedicate', 'anew', 'asked', 'rededicate', 'country']
# ['dedicate', 'deity', 'vow']
# ['change', 'pawn', 'better', 'piece', 'advancing', 'eighth', 'row', 'checker', 'valuable', 'moving', 'closest', 'opponent']
# ['put', 'confide', 'person', 'thing', 'philosopher', 'reposed', 'law', 'people']
# ['reuse', 'material', 'waste', 'product']
# ['present', 'use', 'change']
# ['make', 'property', 'commune', 'community']
# ['share', 'room', 'bed', 'designed', 'one', 'person']
# ['combine', 'common', 'fund', 'pooled', 'resource']
# ['strain', 'excessively', 'overextended', 'accepted', 'additional', 'assignment']
# ['use', 'limit', 'taxing', 'patience']
# ['control', 'function', 'process', 'creation', 'computer', 'computerized', 'car', 'industry', 'live', 'cybernated', 'age', 'cybernate', 'factory']
# ['give', 'workout', 'parent', 'exercise', 'infant', 'personal', 'trainer', 'work', 'hard', 'one', 'muscle', 'puzzle', 'mind']
# ['work', 'excessively', 'hard', 'exploiting', 'student']
# ['put', 'rack', 'pinion', 'camera']
# ['cause', 'preliminary', 'exercise', 'stretch', 'muscle', 'coach', 'warmed', 'player', 'game']

# %%
for key, value in concept_genus_synsets_ranked.items():
    to_print = list()
    for item in value:
        rows = list(item)
        rows.insert(1, item[0].definition().capitalize())
        to_print.append(rows)

    print(f'----- Best 5 sense for {key} -----')
    print()
    print(tabulate(to_print, headers=['Synset', 'Definition', 'Weighted Overlap Score'], tablefmt='orgtbl'))
    print()
# Out:
# ----- Best 5 sense for Emotion -----
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 10
#       8 print(f'----- Best 5 sense for {key} -----')
#       9 print()
# ---> 10 print(tabulate(to_print, headers=['Synset', 'Definition', 'Weighted Overlap Score'], tablefmt='orgtbl'))
#      11 print()
#
# File ~/.local/lib/python3.10/site-packages/tabulate/__init__.py:2048, in tabulate(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2045 if tabular_data is None:
#    2046     tabular_data = []
# -> 2048 list_of_lists, headers = _normalize_tabular_data(
#    2049     tabular_data, headers, showindex=showindex
#    2050 )
#    2051 list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#    2053 if maxcolwidths is not None:
#
# File ~/.local/lib/python3.10/site-packages/tabulate/__init__.py:1471, in _normalize_tabular_data(tabular_data, headers, showindex)
#    1469 headers = list(map(str, headers))
#    1470 #    rows = list(map(list, rows))
# -> 1471 rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1473 # add or remove an index column
#    1474 showindex_is_a_str = type(showindex) in [str, bytes]
#
# File ~/.local/lib/python3.10/site-packages/tabulate/__init__.py:1471, in _normalize_tabular_data.<locals>.<lambda>(r)
#    1469 headers = list(map(str, headers))
#    1470 #    rows = list(map(list, rows))
# -> 1471 rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1473 # add or remove an index column
#    1474 showindex_is_a_str = type(showindex) in [str, bytes]
#
# File ~/.local/lib/python3.10/site-packages/tabulate/__init__.py:107, in _is_separating_line(row)
#     104 def _is_separating_line(row):
#     105     row_type = type(row)
#     106     is_sl = (row_type == list or row_type == str) and (
# --> 107         (len(row) >= 1 and row[0] == SEPARATING_LINE)
#     108         or (len(row) >= 2 and row[1] == SEPARATING_LINE)
#     109     )
#     110     return is_sl
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/reader/wordnet.py:205, in _WordNetObject.__eq__(self, other)
#     204 def __eq__(self, other):
# --> 205     return self._name == other._name
#
# AttributeError: 'str' object has no attribute '_name'
